# %%
# Declare three variables with different types
name = "Muhammad"      # string (str)
age = 25               # integer (int)
height = 5.9           # floating-point number (float)

# Print each on a separate line
print(name)
print(age)
print(height)
# Out:
# Muhammad
# 25
# 5.9

# %%
print("My favorite hobby is")
# Out:
# My favorite hobby is

# %%
hobby = "Reading books"
print("My favorite hobby is:" , hobby)
# Out:
# My favorite hobby is: Reading books

# %%
name = "Sarah"
age = 12
favorite_animal = "dogs"
print("My name is", name ,"i am" , age, "years old" , "and I love", favorite_animal)
# Out:
# My name is Sarah i am 12 years old and I love dogs

# %%
print("Hello, everyone! I am learning Python. 😄")
# Out:
# Hello, everyone! I am learning Python. 😄

# %%
a = 5
b = 7
c = 12 
print(a,b,c)
# Out:
# 5 7 12
